# %%
L = [1, 2, 3, 4]
L[1:3]
# Out:
# [2, 3]

# %%
# init
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import h5py
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

X_train = h5py.File("X_train.h5", "r")
data = X_train["features"][:]
import numpy as np
####Fonction de lissage
def lissage(Lx,Ly,p):
    '''Fonction qui débruite une courbe par une moyenne glissante
    sur 2P+1 points'''
    Lxout=[]
    Lyout=[]
    Lxout = Lx[p: -p]
    for index in range(p, len(Ly)-p):
        average = np.mean(Ly[index-p : index+p+1])
        Lyout.append(average)
    return Lxout,Lyout

# %%
j = 24
plt.plot([i for i in range(1250)], data[j, 11:])
plt.show()

# %%
plt.plot([i for i in range(1250)], data[j, 11:])
x, y = lissage([i for i in range(1250)], data[j, 11:], 20)
plt.plot(x, y)
